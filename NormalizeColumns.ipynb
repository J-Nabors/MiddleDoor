# %%
import pandas as pd

# TODO

# take all columns from an input dataframe and calculate their z-score. 
# create a flexible sanitization structure using a dictonary that can be easily modified in the future
